# %% [markdown]
# This is an exploration of OpenAI engine functionalities

# %%
import os
import openai


# Load your API key from an environment variable or secret management service
openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.Completion.create(engine="text-davinci-002", prompt="Say this is a test", temperature=0, max_tokens=6)

# %%
response
# Out:
# <OpenAIObject text_completion id=cmpl-55hYR29laOyaOHguv7sC6iEiff3rR at 0x10aef1d00> JSON: {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": "\n\nThis is a test"
#     }
#   ],
#   "created": 1652040747,
#   "id": "cmpl-55hYR29laOyaOHguv7sC6iEiff3rR",
#   "model": "text-davinci:002",
#   "object": "text_completion"
# }

# %% [markdown]
# This is list of all engines currently available

# %%
openai.Engine.list()
# Out:
# <OpenAIObject list at 0x10af27240> JSON: {
#   "data": [
#     {
#       "created": null,
#       "id": "ada",
#       "max_replicas": null,
#       "object": "engine",
#       "owner": "openai",
#       "permissions": null,
#       "ready": true,
#       "replicas": null
#     },
#     {
#       "created": null,
#       "id": "ada-code-search-code",
#       "max_replicas": null,
#       "object": "engine",
#       "owner": "openai",
#       "permissions": null,
#       "ready": true,
#       "replicas": null
#     },
#     {
#       "created": null,
#       "id": "ada-code-search-text",
#       "max_replicas": null,
#       "object": "engine",
#       "owner": "openai",
#       "permissions": null,
#       "ready": true,
#       "replicas": null
#     },
#     {
#       "created": null,
#       "id": "ada-search-document",
#       "max_replicas": null,
#       "object": "engine",
#       "owner": "openai",
#       "permissions": null,
#       "ready": true,
#       "replicas": null
# ...

# %% [markdown]
# This is a test of code debugging engine.

# %%
response = openai.Completion.create(
  engine="ada-code-search-code",
  prompt="##### Fix bugs in the below function\n \n### Buggy Python\nimport Random\na = random.randint(1,12)\nb = random.randint(1,12)\nfor i in range(10):\n    question = \"What is \"+a+\" x \"+b+\"? \"\n    answer = input(question)\n    if answer = a*b\n        print (Well done!)\n    else:\n        print(\"No.\")\n    \n### Fixed Python",
  temperature=0,
  max_tokens=182,
  top_p=1.0,
  frequency_penalty=0.0,
  presence_penalty=0.0,
  stop=["###"]
)

# %%
response
# Out:
# <OpenAIObject text_completion id=cmpl-55hmJADlzOUBXSOVziO25LR6sJDZf at 0x10bbfeca0> JSON: {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": "\nimport random\na = random.randint(1,12)\nb = random.randint(1,12)\nfor i in range(10):\n  if a*b == a*b:\n  print(\"No.\")\n  else:\n  print(\"No.\")\n  else:\n  print(\"No.\")\n  else:\n  print(\"No.\")\n  else:\n  print(\"No.\")\n  else:\n  print(\"No.\")\n  else:\n  print(\"No.\")\n  else:\n  print(\"No.\")\n  else:\n  print(\"No.\")\n  else:\n  print(\"No.\")\n  else:\n  print(\"No.\")\n  else:\n  print(\"No.\")\n  else:\n  print(\"No.\")\n  else:\n  print(\"No.\")"
#     }
#   ],
#   "created": 1652041607,
#   "id": "cmpl-55hmJADlzOUBXSOVziO25LR6sJDZf",
#   "model": "code-search-ada:001",
#   "object": "text_completion"
# }
